# %% [markdown]
# # Cannabis Project

# %% [markdown]
# ### Introduction

# %% [markdown]
# here goes the interoduction

# %%
import warnings

# %%
#importing required modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#reading the csv file
df = pd.read_csv('datasets_254652_535029_OCPDB.csv')
df.head()
# Out:
#    OCPID          Strain    SampleID DateRecorded ReportType    ChemicalLab  \
# 0    420          CHEM 4  17002739.0  12 May 2018          C  Cascadia Labs
# 1    421              Z7  17002740.0  12 May 2018          C  Cascadia Labs
# 2    422  ACDC/Harlequin  17002741.0  12 May 2018          C  Cascadia Labs
# 3    423     HarleyWreck  17002742.0  12 May 2018          C  Cascadia Labs
# 4    424    Sour Amnesia  17002833.0  12 May 2018          C  Cascadia Labs
#
#       H2O  TotalTHC    THC  Δ8-THC  ...  ProjectURL  Study  StudyURL  Run  \
# 0   8.60%     193.0  193.0     NaN  ...         NaN    NaN       NaN  NaN
# 1   8.50%       0.0    0.0     NaN  ...         NaN    NaN       NaN  NaN
# 2  14.80%     141.0  141.0     NaN  ...         NaN    NaN       NaN  NaN
# 3   8.40%      75.0   75.0     NaN  ...         NaN    NaN       NaN  NaN
# 4  13.20%     222.0  222.0     NaN  ...         NaN    NaN       NaN  NaN
#
#    RunURL  DatePublished  Spots  Bases  Size  Notes
# 0     NaN            NaN    NaN    NaN   NaN    NaN
# 1     NaN            NaN    NaN    NaN   NaN    NaN
# 2     NaN            NaN    NaN    NaN   NaN    NaN
# 3     NaN            NaN    NaN    NaN   NaN    NaN
# 4     NaN            NaN    NaN    NaN   NaN    NaN
#
# [5 rows x 58 columns]

# %%
#Checking for duplicates
df[df.duplicated(subset=None, keep='first')==True]
# Out:
# Empty DataFrame
# Columns: [OCPID, Strain, SampleID, DateRecorded, ReportType, ChemicalLab, H2O, TotalTHC, THC, Δ8-THC, Δ9-THC, THCA, THCV, TotalCBD, CBDA, CBDV, CBDVA, CBC, CBG, CBN, α-Pinene, Camphene, Myrcene, β-Pinene, 3-Carene, α-Terpinene, D-Limonene, p-Cymene, Ocimene, Eucalyptol, γ-Terpinene, Terpinolene, Linalool, Isopulegol, Geraniol, β-Caryophyllene, α-Humelene, Nerolidol-1, Nerolidol-2, Guaiol, CaryophylleneOxide, α-Bisabolol, GeneticLab, Sample, SampleURL, Organism, OrganismURL, Project, ProjectURL, Study, StudyURL, Run, RunURL, DatePublished, Spots, Bases, Size, Notes]
# Index: []
#
# [0 rows x 58 columns]

# %%
#describing the dataset
df.describe()
# Out:
#              OCPID      SampleID    TotalTHC         THC  Δ8-THC      Δ9-THC  \
# count  1099.000000  2.550000e+02  255.000000  255.000000   159.0  255.000000
# mean    969.000000  1.762509e+07  172.927255  172.927255     0.0    4.159216
# std     317.398278  4.843144e+05   74.996990   74.996990     0.0    5.852526
# min     420.000000  1.700274e+07    0.000000    0.000000     0.0    0.000000
# 25%     694.500000  1.700310e+07  137.860000  137.860000     0.0    0.000000
# 50%     969.000000  1.800063e+07  190.440000  190.440000     0.0    1.570000
# 75%    1243.500000  1.800069e+07  223.095000  223.095000     0.0    6.525000
# max    1518.000000  1.800075e+07  316.600000  316.600000     0.0   34.000000
#
#              THCA   THCV   TotalCBD        CBDA  ...  β-Caryophyllene  \
# count  255.000000  159.0  255.00000  255.000000  ...       255.000000
# mean   173.090196    0.0   20.93298   21.064588  ...         3.072667
# std     75.656729    0.0   45.18685   45.916234  ...         2.183463
# min      0.000000    0.0    0.00000    0.000000  ...         0.000000
# 25%    138.000000    0.0    0.00000    0.000000  ...         1.530000
# 50%    190.000000    0.0    0.00000    0.000000  ...         2.610000
# 75%    225.000000    0.0    0.71000    0.000000  ...         4.065000
# max    323.000000    0.0  197.57000  202.000000  ...        14.250000
#
#        α-Humelene  Nerolidol-1  Nerolidol-2      Guaiol  CaryophylleneOxide  \
# count  255.000000   255.000000   255.000000  255.000000          255.000000
# mean     0.900902     0.028627     0.022431    0.157294            0.000549
# std      0.809311     0.101140     0.100316    0.304647            0.006187
# min      0.000000     0.000000     0.000000    0.000000            0.000000
# 25%      0.335000     0.000000     0.000000    0.000000            0.000000
# 50%      0.780000     0.000000     0.000000    0.000000            0.000000
# 75%      1.250000     0.000000     0.000000    0.190000            0.000000
# max      6.290000     0.720000     0.840000    1.340000            0.070000
#
#        α-Bisabolol         Spots         Bases  Notes
# count   255.000000  8.510000e+02  8.510000e+02    0.0
# mean      0.320902  1.734680e+06  2.617060e+08    NaN
# std       0.393014  2.123216e+06  3.204905e+08    NaN
# min       0.000000  8.603100e+04  1.162497e+07    NaN
# 25%       0.000000  8.807120e+05  1.329917e+08    NaN
# 50%       0.180000  1.212803e+06  1.831155e+08    NaN
# 75%       0.545000  1.907904e+06  2.881210e+08    NaN
# max       2.190000  2.263399e+07  3.418109e+09    NaN
#
# [8 rows x 40 columns]

# %% [markdown]
# No duplicated data exists in the dataset.

# %%
#getting the data types in columns
print(df.dtypes)
# Out:
# OCPID                   int64
# Strain                 object
# SampleID              float64
# DateRecorded           object
# ReportType             object
# ChemicalLab            object
# H2O                    object
# TotalTHC              float64
# THC                   float64
# Δ8-THC                float64
# Δ9-THC                float64
# THCA                  float64
# THCV                  float64
# TotalCBD              float64
# CBDA                  float64
# CBDV                  float64
# CBDVA                 float64
# CBC                   float64
# CBG                   float64
# CBN                   float64
# α-Pinene              float64
# Camphene              float64
# Myrcene               float64
# β-Pinene              float64
# 3-Carene              float64
# α-Terpinene           float64
# D-Limonene            float64
# p-Cymene              float64
# Ocimene               float64
# Eucalyptol            float64
# γ-Terpinene           float64
# Terpinolene           float64
# Linalool              float64
# Isopulegol            float64
# Geraniol              float64
# β-Caryophyllene       float64
# α-Humelene            float64
# Nerolidol-1           float64
# Nerolidol-2           float64
# Guaiol                float64
# CaryophylleneOxide    float64
# α-Bisabolol           float64
# GeneticLab             object
# Sample                 object
# SampleURL              object
# Organism               object
# OrganismURL            object
# Project                object
# ProjectURL             object
# Study                  object
# StudyURL               object
# Run                    object
# RunURL                 object
# DatePublished          object
# Spots                 float64
# Bases                 float64
# Size                   object
# Notes                 float64
# dtype: object

# %%
#Checking to see if there is any null data in our dataset:
df_nulls = df[df.isnull().apply(lambda x: max(x), axis=1)]
# 1077            NaN     NaN       NaN    NaN     NaN  ...
# 1078            NaN     NaN       NaN    NaN     NaN  ...
# 1079            NaN     NaN       NaN    NaN     NaN  ...
# 1080            NaN     NaN       NaN    NaN     NaN  ...
# 1081            NaN     NaN       NaN    NaN     NaN  ...
# 1082            NaN     NaN       NaN    NaN     NaN  ...
# 1083            NaN     NaN       NaN    NaN     NaN  ...
# 1084            NaN     NaN       NaN    NaN     NaN  ...
# 1085            NaN     NaN       NaN    NaN     NaN  ...
# 1086            NaN     NaN       NaN    NaN     NaN  ...
# 1087            NaN     NaN       NaN    NaN     NaN  ...
# 1088            NaN     NaN       NaN    NaN     NaN  ...
# 1089            NaN     NaN       NaN    NaN     NaN  ...
# 1090            NaN     NaN       NaN    NaN     NaN  ...
# 1091            NaN     NaN       NaN    NaN     NaN  ...
# 1092            NaN     NaN       NaN    NaN     NaN  ...
# 1093            NaN     NaN       NaN    NaN     NaN  ...
# 1094            NaN     NaN       NaN    NaN     NaN  ...
# 1095            NaN     NaN       NaN    NaN     NaN  ...
# 1096            NaN     NaN       NaN    NaN     NaN  ...
# 1097            NaN     NaN       NaN    NaN     NaN  ...
# 1098            NaN     NaN       NaN    NaN     NaN  ...
#
#                                              ProjectURL      Study  \
# 0                                                   NaN        NaN
# 1                                                   NaN        NaN
# 2                                                   NaN        NaN
# 3                                                   NaN        NaN
# 4                                                   NaN        NaN
# 5                                                   NaN        NaN
# 6                                                   NaN        NaN
# 7     <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP145424
# 8                                                   NaN        NaN
# 9                                                   NaN        NaN
# 10    <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP145424
# 11                                                  NaN        NaN
# 12                                                  NaN        NaN
# 13                                                  NaN        NaN
# 14                                                  NaN        NaN
# 15                                                  NaN        NaN
# 16                                                  NaN        NaN
# 17                                                  NaN        NaN
# 18                                                  NaN        NaN
# 19                                                  NaN        NaN
# 20                                                  NaN        NaN
# 21                                                  NaN        NaN
# 22                                                  NaN        NaN
# 23                                                  NaN        NaN
# 24    <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP145424
# 25                                                  NaN        NaN
# 26                                                  NaN        NaN
# 27                                                  NaN        NaN
# 28    <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP145424
# 29                                                  NaN        NaN
# ...                                                 ...        ...
# 1069  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1070  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1071  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1072  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1073  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1074  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1075  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1076  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1077  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1078  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1079  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1080  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1081  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1082  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1083  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1084  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1085  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1086  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1087  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1088  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1089  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1090  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1091  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1092  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1093  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1094  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1095  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1096  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1097  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
# 1098  <a href="https://www.ncbi.nlm.nih.gov/bioproje...  SRP092005
#
#                                                StudyURL         Run  \
# 0                                                   NaN         NaN
# 1                                                   NaN         NaN
# 2                                                   NaN         NaN
# 3                                                   NaN         NaN
# 4                                                   NaN         NaN
# 5                                                   NaN         NaN
# 6                                                   NaN         NaN
# 7     <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR7151893
# 8                                                   NaN         NaN
# 9                                                   NaN         NaN
# 10    <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR7151895
# 11                                                  NaN         NaN
# 12                                                  NaN         NaN
# 13                                                  NaN         NaN
# 14                                                  NaN         NaN
# 15                                                  NaN         NaN
# 16                                                  NaN         NaN
# 17                                                  NaN         NaN
# 18                                                  NaN         NaN
# 19                                                  NaN         NaN
# 20                                                  NaN         NaN
# 21                                                  NaN         NaN
# 22                                                  NaN         NaN
# 23                                                  NaN         NaN
# 24    <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR7151889
# 25                                                  NaN         NaN
# 26                                                  NaN         NaN
# 27                                                  NaN         NaN
# 28    <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR7151896
# 29                                                  NaN         NaN
# ...                                                 ...         ...
# 1069  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451193
# 1070  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451194
# 1071  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451195
# 1072  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451196
# 1073  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451197
# 1074  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451198
# 1075  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451199
# 1076  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451200
# 1077  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451201
# 1078  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451202
# 1079  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451203
# 1080  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451204
# 1081  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451205
# 1082  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451206
# 1083  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451207
# 1084  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451208
# 1085  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451209
# 1086  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451210
# 1087  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451211
# 1088  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451212
# 1089  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451213
# 1090  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451214
# 1091  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451215
# 1092  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451216
# 1093  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451217
# 1094  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451218
# 1095  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451219
# 1096  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451220
# 1097  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451221
# 1098  <a href="https://trace.ncbi.nlm.nih.gov/Traces...  SRR4451222
#
#                                                  RunURL  DatePublished  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            NaN
# 5                                                   NaN            NaN
# 6                                                   NaN            NaN
# 7     <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2018-05-11
# 8                                                   NaN            NaN
# 9                                                   NaN            NaN
# 10    <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2018-05-11
# 11                                                  NaN            NaN
# 12                                                  NaN            NaN
# 13                                                  NaN            NaN
# 14                                                  NaN            NaN
# 15                                                  NaN            NaN
# 16                                                  NaN            NaN
# 17                                                  NaN            NaN
# 18                                                  NaN            NaN
# 19                                                  NaN            NaN
# 20                                                  NaN            NaN
# 21                                                  NaN            NaN
# 22                                                  NaN            NaN
# 23                                                  NaN            NaN
# 24    <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2018-05-11
# 25                                                  NaN            NaN
# 26                                                  NaN            NaN
# 27                                                  NaN            NaN
# 28    <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2018-05-11
# 29                                                  NaN            NaN
# ...                                                 ...            ...
# 1069  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1070  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1071  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1072  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1073  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1074  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1075  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1076  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1077  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1078  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1079  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1080  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1081  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1082  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1083  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1084  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1085  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1086  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1087  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1088  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1089  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1090  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1091  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1092  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1093  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1094  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1095  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1096  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1097  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
# 1098  <a href="https://trace.ncbi.nlm.nih.gov/Traces...     2016-10-26
#
#           Spots        Bases      Size  Notes
# 0           NaN          NaN       NaN    NaN
# 1           NaN          NaN       NaN    NaN
# 2           NaN          NaN       NaN    NaN
# 3           NaN          NaN       NaN    NaN
# 4           NaN          NaN       NaN    NaN
# 5           NaN          NaN       NaN    NaN
# 6           NaN          NaN       NaN    NaN
# 7      948527.0  143216564.0   39.7 MB    NaN
# 8           NaN          NaN       NaN    NaN
# 9           NaN          NaN       NaN    NaN
# 10     865078.0  130595016.0   35.7 MB    NaN
# 11          NaN          NaN       NaN    NaN
# 12          NaN          NaN       NaN    NaN
# 13          NaN          NaN       NaN    NaN
# 14          NaN          NaN       NaN    NaN
# 15          NaN          NaN       NaN    NaN
# 16          NaN          NaN       NaN    NaN
# 17          NaN          NaN       NaN    NaN
# 18          NaN          NaN       NaN    NaN
# 19          NaN          NaN       NaN    NaN
# 20          NaN          NaN       NaN    NaN
# 21          NaN          NaN       NaN    NaN
# 22          NaN          NaN       NaN    NaN
# 23          NaN          NaN       NaN    NaN
# 24    1528172.0  230768957.0   77.0 MB    NaN
# 25          NaN          NaN       NaN    NaN
# 26          NaN          NaN       NaN    NaN
# 27          NaN          NaN       NaN    NaN
# 28     806388.0  121758284.0   34.5 MB    NaN
# 29          NaN          NaN       NaN    NaN
# ...         ...          ...       ...    ...
# 1069   739436.0  111577886.0   37.7 MB    NaN
# 1070  1589780.0  240065900.0   86.9 MB    NaN
# 1071   842085.0  127140309.0   42.9 MB    NaN
# 1072  1335395.0  201534467.0   70.3 MB    NaN
# 1073  1516935.0  229021296.0   79.6 MB    NaN
# 1074  1303244.0  196743676.0   67.0 MB    NaN
# 1075  2054180.0  310107697.0  112.4 MB    NaN
# 1076   861591.0  130090884.0   44.0 MB    NaN
# 1077  2130322.0  321574956.0  116.9 MB    NaN
# 1078  3810966.0  575363933.0  261.5 MB    NaN
# 1079  1639529.0  247376258.0   88.9 MB    NaN
# 1080   932701.0  140755597.0   48.8 MB    NaN
# 1081   985181.0  148754392.0   54.1 MB    NaN
# 1082  3599023.0  543275229.0  246.3 MB    NaN
# 1083   788086.0  118929407.0   40.6 MB    NaN
# 1084  1260523.0  190265475.0   69.2 MB    NaN
# 1085  1193137.0  180170281.0   60.6 MB    NaN
# 1086   876513.0  132306203.0   47.5 MB    NaN
# 1087  1598203.0  240456283.0   83.3 MB    NaN
# 1088   872134.0  131663538.0   45.8 MB    NaN
# 1089  1536527.0  232003332.0   79.3 MB    NaN
# 1090   451176.0   68118835.0   23.4 MB    NaN
# 1091  1673065.0  252456907.0   86.3 MB    NaN
# 1092  2028674.0  306259814.0  111.1 MB    NaN
# 1093  2953095.0  445765317.0  204.6 MB    NaN
# 1094   533822.0   80557990.0   27.5 MB    NaN
# 1095   865080.0  130604131.0   44.1 MB    NaN
# 1096  1330032.0  200826515.0   72.0 MB    NaN
# 1097   960826.0  145061119.0   49.9 MB    NaN
# 1098   876249.0  132242494.0   44.6 MB    NaN
#
# [1099 rows x 58 columns]

# %% [markdown]
# In all rows we have null values.

# %%
#finding the number of unique strains in the dataset
df['Strain'].nunique()
# Out:
# 831

# %%
#counting the number of each unique strain in the dataset
df['Strain'].value_counts()
# Out:
# Sour Diesel                         14
# Cannatonic                          12
# Blue Dream                          10
# Gorilla Glue #4                      9
# Kazakhstan                           8
# AC/DC                                8
# Durban Poison                        8
# Jack Herer                           8
# Cinex                                6
# Blotter                              6
# Harlequin                            6
# Root Beer Float                      6
# Black Trinity                        6
# Cinex x 501OG                        5
# Animal Cookies                       5
# Agent Orange x 501OG                 5
# Headband                             5
# Blueberry                            5
# Wedding Cake                         4
# Trainwreck                           4
# Thailand                             4
# Ace of Spades                        4
# Super Lemon Haze                     4
# Purple Hindu Kush                    4
# India                                4
# Afgoo                                4
# Malawi                               4
# Sunset Sherbert                      4
# Dream Queen                          4
# Chernobyl                            4
#                                     ..
# Cherry Cheesecake                    1
# Trainwreck C                         1
# Old Mendo Haze                       1
# Odyssey                              1
# Royal Chem                           1
# Cascade Chronic                      1
# Vortex                               1
# Dad'S Durban Pomegranate             1
# Amnesia                              1
# #5 Pheno                             1
# Tahoe OG                             1
# Super Lemon OG                       1
# Pre-'98 Bubba Kush                   1
# Chemdawg                             1
# Sour Queen                           1
# Berry Beard                          1
# The Real McCoy                       1
# Dawg's Waltz                         1
# White Cookies                        1
# Romulan Grapefruit                   1
# Colombia Sabanira                    1
# Chiang Mai Thailand                  1
# Cindarella 99                        1
# Ghost Dog                            1
# U Dub                                1
# Cascade Lemonade                     1
# Tanzanian C                          1
# Malanje Local 90's Liamba Angola     1
# Voyager 1                            1
# Paraguay 1                           1
# Name: Strain, Length: 831, dtype: int64

# %%
#counting the number of each report type
df['ReportType'].value_counts()
# Out:
# G    844
# C    248
# B      7
# Name: ReportType, dtype: int64

# %%
#checking the titles of the columns in the df
df.columns
# Out:
# Index(['OCPID', 'Strain', 'SampleID', 'DateRecorded', 'ReportType',
#        'ChemicalLab', 'H2O', 'TotalTHC', 'THC', 'Δ8-THC', 'Δ9-THC', 'THCA',
#        'THCV', 'TotalCBD', 'CBDA', 'CBDV', 'CBDVA', 'CBC', 'CBG', 'CBN',
#        'α-Pinene', 'Camphene', 'Myrcene', 'β-Pinene', '3-Carene',
#        'α-Terpinene', 'D-Limonene', 'p-Cymene', 'Ocimene', 'Eucalyptol',
#        'γ-Terpinene', 'Terpinolene', 'Linalool', 'Isopulegol', 'Geraniol',
#        'β-Caryophyllene', 'α-Humelene', 'Nerolidol-1', 'Nerolidol-2', 'Guaiol',
#        'CaryophylleneOxide', 'α-Bisabolol', 'GeneticLab', 'Sample',
#        'SampleURL', 'Organism', 'OrganismURL', 'Project', 'ProjectURL',
#        'Study', 'StudyURL', 'Run', 'RunURL', 'DatePublished', 'Spots', 'Bases',
#        'Size', 'Notes'],
#       dtype='object')

# %%
#droping the columns which have no vlues in them or have useless values (same values)
df = df.drop(['OCPID','DateRecorded', 'SampleID', 'ReportType','ChemicalLab', 'Δ8-THC', 'THCV', 'CBDV', 'CBN', 'GeneticLab', 'Sample', 'SampleURL',
             'Organism', 'OrganismURL', 'Project', 'ProjectURL',
       'Study', 'StudyURL', 'Run', 'RunURL', 'DatePublished', 'Spots', 'Bases',
       'Size', 'Notes'], axis=1)

# %%
#checking the head of the cleaned df
df.head()
# Out:
#            Strain     H2O  TotalTHC    THC  Δ9-THC   THCA  TotalCBD   CBDA  \
# 0          CHEM 4   8.60%     193.0  193.0     0.0  203.0       0.0    0.0
# 1              Z7   8.50%       0.0    0.0     0.0    0.0     140.0  147.0
# 2  ACDC/Harlequin  14.80%     141.0  141.0     0.0  138.0      56.0   55.0
# 3     HarleyWreck   8.40%      75.0   75.0     0.0   79.0      38.0   40.0
# 4    Sour Amnesia  13.20%     222.0  222.0     0.0  222.0       0.0    0.0
#
#    CBDVA  CBC  ...  Linalool  Isopulegol  Geraniol  β-Caryophyllene  \
# 0    NaN  NaN  ...      0.37         0.0       0.0             5.48
# 1    NaN  NaN  ...      0.25         0.0       0.0             2.35
# 2    NaN  NaN  ...      0.39         0.0       0.0             3.11
# 3    NaN  NaN  ...      0.42         0.0       0.0             2.95
# 4    NaN  NaN  ...      0.28         0.0       0.0             1.42
#
#    α-Humelene  Nerolidol-1  Nerolidol-2  Guaiol  CaryophylleneOxide  \
# 0        2.03          0.0          0.0    0.00                 0.0
# 1        1.14          0.0          0.0    0.25                 0.0
# 2        1.20          0.0          0.0    0.20                 0.0
# 3        0.99          0.0          0.0    0.25                 0.0
# 4        0.58          0.0          0.0    0.00                 0.0
#
#    α-Bisabolol
# 0         0.87
# 1         0.62
# 2         0.32
# 3         0.25
# 4         0.19
#
# [5 rows x 33 columns]

# %%
#replacing 
df['H2O']=df['H2O'].str.replace("%","")
df['H2O'] = pd.to_numeric(df['H2O'], errors='coerce')

# %%
#checking the titles of the columns in the df
df.columns
# Out:
# Index(['Strain', 'H2O', 'TotalTHC', 'THC', 'Δ9-THC', 'THCA', 'TotalCBD',
#        'CBDA', 'CBDVA', 'CBC', 'CBG', 'α-Pinene', 'Camphene', 'Myrcene',
#        'β-Pinene', '3-Carene', 'α-Terpinene', 'D-Limonene', 'p-Cymene',
#        'Ocimene', 'Eucalyptol', 'γ-Terpinene', 'Terpinolene', 'Linalool',
#        'Isopulegol', 'Geraniol', 'β-Caryophyllene', 'α-Humelene',
#        'Nerolidol-1', 'Nerolidol-2', 'Guaiol', 'CaryophylleneOxide',
#        'α-Bisabolol'],
#       dtype='object')

# %%
#selecting the right columns for the dataframe
newdf = df[['Strain','H2O','TotalTHC','THC', 'THCA', 'CBG', 'α-Pinene', 'Myrcene', 'β-Pinene', 'D-Limonene', 'Linalool', 'β-Caryophyllene',
'α-Humelene', 'α-Bisabolol']]

# %%
cleandf = newdf.dropna()

# %%
warnings.filterwarnings("ignore")
sns.set()
fig, ((ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9,ax10,ax11,ax12))=plt.subplots(ncols=12,nrows=1,figsize=(15,6)) 
sns.distplot(cleandf['H2O'],ax=ax1);
sns.distplot(cleandf['TotalTHC'],ax=ax2);            
sns.distplot(cleandf['THC'],ax=ax3);
sns.distplot(cleandf['THCA'],ax=ax4);
sns.distplot(cleandf['CBG'],ax=ax5);
sns.distplot(cleandf['α-Pinene'],ax=ax6);
sns.distplot(cleandf['Myrcene'],ax=ax7);
sns.distplot(cleandf['β-Pinene'],ax=ax8);
sns.distplot(cleandf['D-Limonene'],ax=ax9);
sns.distplot(cleandf['Linalool'],ax=ax10);
sns.distplot(cleandf['α-Humelene'],ax=ax11);
sns.distplot(cleandf['α-Bisabolol'],ax=ax12);

plt.savefig('1.png')

# %% [markdown]
# All the selected features are relatively normally distibuted.

# %%
plt.figure(figsize = (12, 8))

ax=sns.stripplot(x='Strain',y='TotalTHC', data=cleandf,jitter=True)

plt.xticks(rotation = 90)
for p in plot.patches:
    plot.annotate(p.get_height(), 
                        (p.get_x() + p.get_width() / 2.0, 
                         p.get_height()), 
                        ha = 'center', 
                        va = 'center', 
                        xytext = (0, 5),
                        textcoords = 'offset points')

plt.title("Price of cars based on Make")
plt.xlabel("Make")
plt.ylabel("Price")
plt.savefig('2.png')
